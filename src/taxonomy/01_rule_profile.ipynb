# %%
# ============================================================
# 1. Config
# ============================================================

from __future__ import annotations

from dataclasses import dataclass

# --------------------------------------------------
# Project
# --------------------------------------------------

PROJECT_NAME = "VOC AI Platform"

PIPELINE_VERSION = "0.1.0"
TAXONOMY_VERSION = "0.1.0"

PROMPT_VERSION = "rule_profile_0.1.0"

ENDPOINT = "databricks-gpt-5-4"

# --------------------------------------------------
# Database
# --------------------------------------------------

SAVE_DB = "sandbox.z_jungryo_lee"

SOURCE_TABLE = "kic_data_ods.buzzmetrix.buzzmetrix"

RULE_PROFILE_TABLE = f"{SAVE_DB}.voc_ai_taxonomy_rule_profile"

RULE_PROFILE_PROGRESS_TABLE = (
    f"{SAVE_DB}.voc_ai_taxonomy_rule_profile_progress"
)

RULE_PROFILE_FAILED_TABLE = (
    f"{SAVE_DB}.voc_ai_taxonomy_rule_profile_failed"
)

# --------------------------------------------------
# Sampling
# --------------------------------------------------

MIN_GROUP_SIZE = 100

MAX_SAMPLE_ROWS = 800

LIMIT_GROUP_COUNT = None

# --------------------------------------------------
# LLM
# --------------------------------------------------

MAX_TOKENS = 2200

MAX_RETRIES = 3

BACKOFF_BASE = 1.8

RATE_LIMIT_SECONDS = 0.4

TEMPERATURE = 0.0

# --------------------------------------------------
# Pipeline
# --------------------------------------------------

RESUME_FROM_CHECKPOINT = True

AUTO_DS_REVIEW = True

# --------------------------------------------------
# Metadata
# --------------------------------------------------

REVIEW_STATUS = "ds_auto_approved"

PIPELINE_STAGE = "rule_profile"

# --------------------------------------------------
# Display
# --------------------------------------------------

print("=" * 60)
print(PROJECT_NAME)
print("=" * 60)

print(f"Pipeline Version : {PIPELINE_VERSION}")
print(f"Taxonomy Version : {TAXONOMY_VERSION}")
print(f"Prompt Version   : {PROMPT_VERSION}")
print(f"Endpoint         : {ENDPOINT}")

print("-" * 60)

print(f"Source           : {SOURCE_TABLE}")

print(f"Rule Profile     : {RULE_PROFILE_TABLE}")

print("=" * 60)
